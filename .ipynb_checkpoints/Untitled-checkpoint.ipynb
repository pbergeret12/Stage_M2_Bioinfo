# %%
pip install nilearn
# Out:
# Collecting nilearn
#   Downloading nilearn-0.9.1-py3-none-any.whl (9.6 MB)
#      |████████████████████████████████| 9.6 MB 10.1 MB/s eta 0:00:01
# Requirement already satisfied: scikit-learn>=0.22 in /home/pierre/anaconda3/lib/python3.9/site-packages (from nilearn) (0.24.2)
# Collecting nibabel>=3.0.0
#   Downloading nibabel-3.2.2-py3-none-any.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 18.1 MB/s eta 0:00:01
# Requirement already satisfied: requests>=2 in /home/pierre/anaconda3/lib/python3.9/site-packages (from nilearn) (2.26.0)
# Requirement already satisfied: pandas>=1.0 in /home/pierre/anaconda3/lib/python3.9/site-packages (from nilearn) (1.3.4)
# Requirement already satisfied: scipy>=1.5 in /home/pierre/anaconda3/lib/python3.9/site-packages (from nilearn) (1.7.1)
# Requirement already satisfied: joblib>=0.15 in /home/pierre/anaconda3/lib/python3.9/site-packages (from nilearn) (1.1.0)
# Requirement already satisfied: lxml in /home/pierre/anaconda3/lib/python3.9/site-packages (from nilearn) (4.6.3)
# Requirement already satisfied: numpy>=1.18 in /home/pierre/anaconda3/lib/python3.9/site-packages (from nilearn) (1.20.3)
# Requirement already satisfied: packaging>=14.3 in /home/pierre/anaconda3/lib/python3.9/site-packages (from nibabel>=3.0.0->nilearn) (21.0)
# Requirement already satisfied: setuptools in /home/pierre/anaconda3/lib/python3.9/site-packages (from nibabel>=3.0.0->nilearn) (58.0.4)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/pierre/anaconda3/lib/python3.9/site-packages (from packaging>=14.3->nibabel>=3.0.0->nilearn) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/pierre/anaconda3/lib/python3.9/site-packages (from pandas>=1.0->nilearn) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/pierre/anaconda3/lib/python3.9/site-packages (from pandas>=1.0->nilearn) (2021.3)
# Requirement already satisfied: six>=1.5 in /home/pierre/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas>=1.0->nilearn) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/pierre/anaconda3/lib/python3.9/site-packages (from requests>=2->nilearn) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/pierre/anaconda3/lib/python3.9/site-packages (from requests>=2->nilearn) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/pierre/anaconda3/lib/python3.9/site-packages (from requests>=2->nilearn) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/pierre/anaconda3/lib/python3.9/site-packages (from requests>=2->nilearn) (1.26.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/pierre/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.22->nilearn) (2.2.0)
# Installing collected packages: nibabel, nilearn
# Successfully installed nibabel-3.2.2 nilearn-0.9.1
# Note: you may need to restart the kernel to use updated packages.

# %%
###9.1.1

# import numpy: the module providing numerical arrays
import numpy as np
t = np.linspace(1, 10, 2000)

## linspace: ici 2000 points à égale distance entre 1 et 10

# %%
# import matplotlib.pyplot: the module for scientific plotting
import matplotlib.pyplot as plt
plt.plot(t, np.cos(t))

# %%
###9.1.2

# Let us use a Nifti file that is shipped with nilearn
from nilearn.datasets import MNI152_FILE_PATH

# Note that the variable MNI152_FILE_PATH is just a path to a Nifti file
print('Path to MNI152 template: %r' % MNI152_FILE_PATH)
# Out:
# Path to MNI152 template: '/home/pierre/anaconda3/lib/python3.9/site-packages/nilearn/datasets/data/mni_icbm152_t1_tal_nlin_sym_09a_converted.nii.gz'

# %%
### fonction la plus basique pour plot

from nilearn import plotting
plotting.plot_img(MNI152_FILE_PATH)

# %%
from nilearn import image
smooth_anat_img = image.smooth_img(MNI152_FILE_PATH, fwhm=3)

# While we are giving a file name as input, the function returns
# an in-memory object:
smooth_anat_img

# %%
plotting.plot_img(smooth_anat_img)

# %%
### on refait passer le smooth dans une fonction de smooth
more_smooth_anat_img = image.smooth_img(smooth_anat_img, fwhm=3)
plotting.plot_img(more_smooth_anat_img)

# %%
more_smooth_anat_img.to_filename('more_smooth_anat_img.nii.gz')

# %%
### pour plot en dohors de python
plotting.show()
